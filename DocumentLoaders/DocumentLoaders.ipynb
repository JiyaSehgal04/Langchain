# %% [markdown]
# DOCUMENT LOADERS

# %%
# TextLoaders
from langchain_community.document_loaders import TextLoader


loader=TextLoader("doc.txt", encoding="utf-8")
docs=loader.load()
print(docs)
# Out:
# [Document(metadata={'source': 'doc.txt'}, page_content='Rising temperatures in Antarctica are having profound and cascading effects on its wildlife and marine ecosystems, primarily driven by the rapid loss of sea ice and warming ocean waters. Sea ice serves as a critical habitat and breeding platform for species such as emperor and Adélie penguins, whose populations are declining as reduced ice coverage disrupts nesting, chick survival, and access to food. Warmer ocean temperatures are also altering the distribution and abundance of Antarctic krill, a keystone species that forms the foundation of the Southern Ocean food web, directly impacting seals, whales, and seabirds that depend on krill for survival. Additionally, melting glaciers increase freshwater input into the ocean, changing salinity levels and nutrient mixing, which affects phytoplankton productivity and, in turn, higher trophic levels. Antarctic seals, including Weddell and crabeater seals, face increased stress due to habitat loss, shifting prey availability, and greater exposure to predators and human activity. Collectively, these changes threaten the long-term stability of Antarctic biodiversity and highlight the sensitivity of polar ecosystems to even small increases in global temperatures.\n')]

# %%
#PDFLoaders
from langchain_community.document_loaders import PyPDFLoader

loader=PyPDFLoader("blue_pottery_timeline_with_years.pdf")
docs=loader.load()
print(docs)
# Out:
# [Document(metadata={'producer': 'PyFPDF 1.7.2 http://pyfpdf.googlecode.com/', 'creator': 'PyPDF', 'creationdate': 'D:20250812100334', 'source': 'blue_pottery_timeline_with_years.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content="Timeline of Blue Pottery in India\nA concise history of Jaipur's world-famous blue pottery, from ancient origins to\nmodern revival.\nHarappan Pottery (c. 3300-1300 BCE)\nWheel-turned terracotta jars, bowls, and beakers painted in red and black with geometric and animal\nmotifs, setting the base for Indian pottery traditions.\nMauryan & Gupta Pottery (c. 322 BCE - 550 CE)\nMauryan Northern Black Polished Ware for elites; Gupta pottery added carved floral and animal\nmotifs, blending utility with decorative appeal.\nArrival of Glazed Pottery (c. 1206-1526 CE)\nPersian artisans introduced mineral-glazed turquoise, green, and blue pottery under the Delhi\nSultanate and Mughals, adorning mosques and palaces.\nBirth of Jaipur Blue Pottery (c. 1727-1799 CE)\nRajasthan artisans used quartz instead of clay, creating translucent pottery with cobalt blue\nPersian-inspired floral, bird, and lattice motifs.\nRoyal Patronage & Flourishing (c. 1800-1900 CE)\nJaipur rulers funded workshops, producing grand vases, ornate tiles, and crockery with lotus,\npeacock, and elephant motifs for palaces and temples.\nDecline & Near Extinction (c. 1900-1947 CE)\nLoss of royal patronage and high pigment costs reduced production to small trinkets; only a few\nartisans kept the tradition alive.\nRevival & Preservation (c. 1950-1975 CE)\nNGOs, craft enthusiasts, and Jaipur royals revived the craft, training artisans in traditional quartz\ntechniques and promoting it at exhibitions.\nModern Era (2000-Present)\nGI-tagged Jaipur Blue Pottery is now a global craft, blending traditional cobalt blue with modern\ndesigns for domestic and export markets.")]

# %%
#DirectoryLoader
from langchain_community.document_loaders import DirectoryLoader

loader=DirectoryLoader(path="books",glob="*.pdf")
doc=loader.lazy_load()
for documents in doc:
    print(documents)

# %%
#WebBaseLoader
from langchain_community.document_loaders import WebBaseLoader

url="https://www.google.com"
loader=WebBaseLoader(url)
docs=loader.load()
print(docs)
# Out:
# [Document(metadata={'source': 'https://www.google.com', 'title': 'Google', 'language': 'en-IN'}, page_content='GoogleSearch Images Maps Play YouTube News Gmail Drive More »Web History | Settings | Sign in\xa0Advanced searchGoogle offered in:  हिन्दी বাংলা తెలుగు मराठी தமிழ் ગુજરાતી ಕನ್ನಡ മലയാളം ਪੰਜਾਬੀ AdvertisingBusiness SolutionsAbout GoogleGoogle.co.in© 2025 - Privacy - Terms')]
