# %%
from langchain_core.tools import tool

# %%
@tool
def add(a:int,b:int)->int:
    """Add two numbers together"""
    return a+b

@tool
def subtract(a:int,b:int)->int:
    """Subtract two numbers"""
    return a-b

@tool
def multiply(a:int,b:int)->int:
    """Multiply two numbers"""
    return a*b

class MathToolKit:
    def get_tools(self):
        return [add,subtract,multiply]


toolkit=MathToolKit()
tools=toolkit.get_tools()
for t1 in tools:
    print(t1.name,"-->",t1.description)
# Out:
# add --> Add two numbers together
# subtract --> Subtract two numbers
# multiply --> Multiply two numbers

# %%
@tool
def sub(a:int,b:int)->int:
    """Subtract two numbers"""
    return a-b

@tool
def multiply(a:int,b:int)->int:
    """Multiply two numbers"""
    return a*b



class MathToolKit:
    def get_tools(self):
        return [sub,multiply]


toolkit=MathToolKit()
tools=toolkit.get_tools()xs


#in the mathtoolkit class we define the function for each of these tools to be binded and implemented into one
#we are implementing the class Mathtoolkit and then using the method of get_tools of the toolkit
