# %%
from langchain.output_parsers import StructuredOutputParser
from langchain.output_parsers import OutputFixingParser
from langchain.output_parsers import ResponseSchema
from langchain_core.prompts import PromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
from typing import TypedDict, Annotated, Optional, Literal
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from langchain.output_parsers import StructuredOutputParser
#       2 from langchain.output_parsers import OutputFixingParser
#       3 from langchain.output_parsers import ResponseSchema
#
# ModuleNotFoundError: No module named 'langchain.output_parsers'

# %%
load_dotenv()
model=ChatGoogleGenerativeAI(model="gemini-2.5-flash")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 load_dotenv()
#       2 model=ChatGoogleGenerativeAI(model="gemini-2.5-flash")
#
# NameError: name 'load_dotenv' is not defined

# %%
#schema

Schema=[
    ResponseSchema(name="fact1",description="First fact about the given topic"),
    ResponseSchema(name="fact2",description="Second fact about the given topic"),
    ResponseSchema(name="fact3",description="Third fact about the given topic"),
    ResponseSchema(name="fact4",description="Fourth fact about the given topic"),
]

parser=StructuredOutputParser.from_response_schemas(Schema)
safe_parser=OutputFixingParser.from_llm(llm=model, parser=parser)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 #schema
#       3 Schema=[
# ----> 4     ResponseSchema(name="fact1",description="First fact about the given topic"),
#       5     ResponseSchema(name="fact2",description="Second fact about the given topic"),
#       6     ResponseSchema(name="fact3",description="Third fact about the given topic"),
#       7     ResponseSchema(name="fact4",description="Fourth fact about the given topic"),
#       8 ]
#      10 parser=StructuredOutputParser.from_response_schemas(Schema)
#      11 safe_parser=OutputFixingParser.from_llm(llm=model, parser=parser)
#
# NameError: name 'ResponseSchema' is not defined

# %%
template=PromptTemplate(
    template="""Give me a total of 4 facts about the given topic of {topic}. \n  
    {response_format}""",
    input_variables=['topic'],
    partial_variables={'response_format':parser.get_format_instructions()}
)


chain=template|model | parser


result=chain.invoke({"topic":"Black Holes"})
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 template=PromptTemplate(
#       2     template="""Give me a total of 4 facts about the given topic of {topic}. \n
#       3     {response_format}""",
#       4     input_variables=['topic'],
#       5     partial_variables={'response_format':parser.get_format_instructions()}
#       6 )
#       9 chain=template|model | parser
#      12 result=chain.invoke({"topic":"Black Holes"})
#
# NameError: name 'PromptTemplate' is not defined
