# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv



load_dotenv()
# Out:
# True

# %%
chat=ChatPromptTemplate.from_template([
    ('system',"You are a helpful {field} assistant that can answer questions and help with tasks."),
    ('user',"Explain the meaning of {input}")
])

prompt=chat.invoke({
    'field':"physics",
    'input':"dark matter and time space complexity"
})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 chat=ChatPromptTemplate.from_template([
#       2     ('system',"You are a helpful {field} assistant that can answer questions and help with tasks."),
#       3     ('user',"Explain the meaning of {input}")
#       4 ])
#       6 prompt=chat.invoke({
#       7     'field':"physics",
#       8     'input':"dark matter and time space complexity"
#       9 })
#
# File ~/miniconda3/lib/python3.13/site-packages/langchain_core/prompts/chat.py:1096, in ChatPromptTemplate.from_template(cls, template, **kwargs)
#    1082 @classmethod
#    1083 def from_template(cls, template: str, **kwargs: Any) -> ChatPromptTemplate:
#    1084     """Create a chat prompt template from a template string.
#    1085
#    1086     Creates a chat template consisting of a single message assumed to be from
#    (...)   1094         A new instance of this class.
#    1095     """
# -> 1096     prompt_template = PromptTemplate.from_template(template, **kwargs)
#    1097     message = HumanMessagePromptTemplate(prompt=prompt_template)
#    1098     return cls.from_messages([message])
#
# File ~/miniconda3/lib/python3.13/site-packages/langchain_core/prompts/prompt.py:289, in PromptTemplate.from_template(cls, template, template_format, partial_variables, **kwargs)
#     251 @classmethod
#     252 def from_template(
#     253     cls,
#    (...)    258     **kwargs: Any,
#     259 ) -> PromptTemplate:
#     260     """Load a prompt template from a template.
#     261
#     262     *Security warning*:
#    (...)    287         The prompt template loaded from the template.
#     288     """
# --> 289     input_variables = get_template_variables(template, template_format)
#     290     partial_variables_ = partial_variables or {}
#     292     if partial_variables_:
#
# File ~/miniconda3/lib/python3.13/site-packages/langchain_core/prompts/string.py:264, in get_template_variables(template, template_format)
#     261     input_variables = _get_jinja2_variables_from_template(template)
#     262 elif template_format == "f-string":
#     263     input_variables = {
# --> 264         v for _, v, _, _ in Formatter().parse(template) if v is not None
#     265     }
#     266 elif template_format == "mustache":
#     267     input_variables = mustache_template_vars(template)
#
# File ~/miniconda3/lib/python3.13/string.py:288, in Formatter.parse(self, format_string)
#     287 def parse(self, format_string):
# --> 288     return _string.formatter_parser(format_string)
#
# TypeError: expected str, got list
