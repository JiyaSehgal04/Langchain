# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage
from dotenv import load_dotenv


load_dotenv()
# Out:
# True

# %%
model=ChatGoogleGenerativeAI(model="gemini-2.5-flash")

chat_template=ChatPromptTemplate([
    ("system", "You are a helpful {domain} expert."),
    ("human", "Explain the concept of {topic} in a way that is easy to understand."),
])


prompt=chat_template.invoke({
    "domain": "AI",
    "topic": "Machine Learning"
})

result=model.invoke(prompt.to_messages())

print(result.content)
# Out:
# Imagine you want to teach a computer to do something, but instead of writing out *every single step* and *every single rule* for it to follow (which can be incredibly complicated or even impossible!), you just show it a bunch of examples and let it figure things out for itself.
#
# That, in a nutshell, is **Machine Learning (ML)**.
#
# Think of it like this:
#
# **The Traditional Way (Programming):**
# You want to teach a computer to identify a cat in a photo.
# *   You'd have to write code that says: "If it has pointed ears AND whiskers AND a tail AND is furry AND has specific eye shapes... then it's a cat."
# *   This becomes extremely difficult because what if the cat is sideways? What if it's a hairless cat? What if it's a kitten? You'd need thousands of rules for every possibility.
#
# **The Machine Learning Way:**
# *   **Step 1: Data (Show Examples):** You show the computer thousands, even millions, of pictures. Some are labeled "cat," and some are labeled "not a cat."
# *   **Step 2: Training (Learning):** The computer "studies" all these pictures. It looks for patterns, features, and relationships that distinguish a cat from a non-cat. It learns what makes a cat *a cat*, without you explicitly telling it "pointed ears." It might figure out that furry textures or certain eye patterns are strong indicators.
# *   **Step 3: Model (The Learned Knowledge):** After training, the computer develops an internal "model" – essentially, its own understanding or "brain" about what a cat looks like.
# *   **Step 4: Prediction/Decision (Putting it to Use):** Now, you give the computer a *new* photo it's never seen before. Using its learned "model," it can confidently say, "Yep, that's a cat!" or "Nope, that's a dog."
#
# **Key Idea:** Instead of *explicitly programming* the rules, you give the computer the ability to *learn the rules itself* from data.
#
# **Why is this powerful?**
#
# *   **Too Complex for Humans:** Some problems have so many variables or subtle patterns that humans can't write all the rules (e.g., predicting stock market movements, understanding human speech).
# *   **Constantly Changing:** Rules might change over time (e.g., what constitutes spam email evolves). ML systems can adapt by being re-trained with new data.
# *   **Discovering Hidden Patterns:** ML can find correlations and insights in vast amounts of data that a human might never notice.
#
# **Where do you see Machine Learning every day?**
#
# *   **Recommendation Systems:** Netflix suggesting movies, Amazon suggesting products ("Customers who bought this also bought...")
# *   **Spam Filters:** Automatically sending junk mail to your spam folder.
# *   **Voice Assistants:** Siri, Alexa, Google Assistant understanding your commands.
# *   **Facial Recognition:** Unlocking your phone with your face, tagging friends in photos.
# *   **Self-Driving Cars:** Recognizing pedestrians, traffic signs, and other vehicles.
# *   **Medical Diagnosis:** Helping doctors identify diseases from X-rays or scans.
#
# So, Machine Learning is essentially about teaching computers to learn from experience (data), just like humans do, enabling them to make predictions or decisions without being explicitly programmed for every single scenario.
