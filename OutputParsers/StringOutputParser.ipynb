# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
from typing import TypedDict, Annotated, Optional, Literal

# %%
load_dotenv()
model=ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
template1=PromptTemplate(template="Write a short story about {topic}",
                         input_variable=['topic'])

template2=PromptTemplate(template="Write 4 points summary for the provided {text}",
                         input_variable=['text'])

parser=StrOutputParser()

chain=template1|model|parser|template2|model|parser

result=chain.invoke({"topic":"Black Holes"})
print(result)
# Out:
# Here are 4 points summarizing the provided story:
#
# 1.  **Grief-Driven Journey:** Lyra, consumed by profound grief for her twin sister, Elara, deliberately pilots her ship, the *Stardust*, towards 'The Great Inhaler'—a supermassive black hole at the heart of the Andromeda galaxy—seeking an end to her pain or an answer about existence.
# 2.  **Surrender to the Void:** Ignoring all ship warnings and the intense forces of the accretion disk, Lyra surrenders her ship to the black hole's pull, crossing the event horizon where conventional time and space cease to have meaning.
# 3.  **Cosmic Transformation:** Inside the event horizon, Lyra experiences a gentle, non-painful "spaghettification," her physical and mental essence stretching and unraveling into the singularity, dissolving her individual perception.
# 4.  **Ultimate Revelation & Peace:** In her final moments, Lyra achieves a profound understanding: the black hole isn't an end but a cosmic recycler, confirming that Elara (and all existence) is merely transformed, not destroyed. This realization brings her liberating peace as she and her ship merge with the black hole's eternal cycle.
