# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
chat_template=ChatPromptTemplate([
    ("system", "You are a helpful customer care assistant."),
    MessagesPlaceholder(variable_name="chat_history"),
    ("human", "{input}"),
])

# %%
#Load the chat history


model=ChatGoogleGenerativeAI(model="gemini-2.5-flash")

chat_history=[]
with open("ChatHistory.txt") as file:
    chat_history.extend(file.readlines())

    prompt=chat_template.invoke({
        "chat_history": chat_history,
        "input": "What is the return policy?"
    })

result=model.invoke(prompt.to_messages())

print(result.content)
# Out:
# I can certainly help you with that! At ShopEase, we want you to be completely satisfied with your purchases.
#
# Here's a general overview of our return policy:
#
# *   **Return Window:** Most items can be returned within **30 days** of delivery.
# *   **Item Condition:** Items must be returned in their original condition, unused, with all tags and packaging intact.
# *   **Initiating a Return:** You can easily initiate a return through your ShopEase account by going to your "Order History" and selecting the "Return Item" option next to the relevant purchase.
# *   **Refund Processing:** Once we receive and inspect your returned item, your refund will be processed to your original payment method within 5-7 business days.
#
# Please note that some categories, like perishable goods, intimate apparel, or digital products, might have specific return guidelines. You can find the full details of our return policy on our website under the "Help" or "Customer Service" section.
#
# Is there a specific item you are considering returning, or a particular aspect of the policy you'd like more information on? I'm here to help!
